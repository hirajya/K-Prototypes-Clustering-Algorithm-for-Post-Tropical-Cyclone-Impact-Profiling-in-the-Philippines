# %%
# Core data manipulation and numerical libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Scikit-learn components
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import DBSCAN

# Hyperparameter optimization
import optuna

# Surrogate model 
import xgboost as xgb

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# Set style for better plots
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

# %%
df = pd.read_csv('data/typhoon_impact_with_extreme_weather.csv')
df.head()
# Out:
#   Typhoon Name  Year  Region Province City/Municipality  Families  Person  \
# 0        BETTY  2023       2  BATANES             BASCO      3608   11120
# 1        BETTY  2023       2  BATANES           ITBAYAT       968    3028
# 2        BETTY  2023       2  BATANES             IVANA       444    1532
# 3        BETTY  2023       2  BATANES           MAHATAO       575    1792
# 4        BETTY  2023       2  BATANES           SABTANG       575    1955
#
#    Brgy  Dead  Injured/Ill  ...   PAR_END  Duration_in_PAR_Hours  \
# 0     6     0            0  ...  6/1/2023                  133.0
# 1     5     0            0  ...  6/1/2023                  133.0
# 2     4     0            0  ...  6/1/2023                  133.0
# 3     4     0            0  ...  6/1/2023                  133.0
# 4     6     0            0  ...  6/1/2023                  133.0
#
#    Max_Sustained_Wind_kph  Typhoon_Type  Max_24hr_Rainfall_mm  \
# 0                     195           STY                  25.6
# 1                     195           STY                  20.3
# 2                     195           STY                  25.6
# 3                     195           STY                  25.6
# 4                     195           STY                  25.6
#
#    Total_Storm_Rainfall_mm Min_Pressure_hPa Weather_Station_Mapped  \
# 0                    39.00            977.1                      1
# 1                    32.71           1000.5                      1
# 2                    39.00            977.1                      1
# 3                    39.00            977.1                      1
# 4                    39.00            977.1                      1
#
#    Weather_Records_Found Weather_Days_Covered
# 0                      6                    6
# 1                      6                    6
# 2                      6                    6
# 3                      6                    6
# 4                      6                    6
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1776 entries, 0 to 1775
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Typhoon Name             1776 non-null   object
#  1   Year                     1776 non-null   int64
#  2   Region                   1776 non-null   int64
#  3   Province                 1776 non-null   object
#  4   City/Municipality        1776 non-null   object
#  5   Families                 1776 non-null   int64
#  6   Person                   1776 non-null   int64
#  7   Brgy                     1776 non-null   int64
#  8   Dead                     1776 non-null   int64
#  9   Injured/Ill              1776 non-null   int64
#  10  Missing                  1776 non-null   int64
#  11  Totally                  1776 non-null   int64
#  12  Partially                1776 non-null   int64
#  13  Total                    1776 non-null   int64
#  14  Quantity                 1776 non-null   int64
#  15  Cost                     1776 non-null   float64
#  16  Nearest_Station          1776 non-null   object
#  17  Station_Province         1776 non-null   object
#  18  Distance_km              1776 non-null   float64
#  19  PAR_START                1776 non-null   object
#  20  PAR_END                  1776 non-null   object
#  21  Duration_in_PAR_Hours    1776 non-null   float64
#  22  Max_Sustained_Wind_kph   1776 non-null   int64
#  23  Typhoon_Type             1776 non-null   object
#  24  Max_24hr_Rainfall_mm     1776 non-null   float64
#  25  Total_Storm_Rainfall_mm  1776 non-null   float64
#  26  Min_Pressure_hPa         1776 non-null   float64
#  27  Weather_Station_Mapped   1776 non-null   int64
#  28  Weather_Records_Found    1776 non-null   int64
#  29  Weather_Days_Covered     1776 non-null   int64
# dtypes: float64(6), int64(16), object(8)
# memory usage: 416.4+ KB

# %%
df.isnull().sum()
# Out:
# Typhoon Name               0
# Year                       0
# Region                     0
# Province                   0
# City/Municipality          0
# Families                   0
# Person                     0
# Brgy                       0
# Dead                       0
# Injured/Ill                0
# Missing                    0
# Totally                    0
# Partially                  0
# Total                      0
# Quantity                   0
# Cost                       0
# Nearest_Station            0
# Station_Province           0
# Distance_km                0
# PAR_START                  0
# PAR_END                    0
# Duration_in_PAR_Hours      0
# Max_Sustained_Wind_kph     0
# Typhoon_Type               0
# Max_24hr_Rainfall_mm       0
# Total_Storm_Rainfall_mm    0
# Min_Pressure_hPa           0
# Weather_Station_Mapped     0
# Weather_Records_Found      0
# Weather_Days_Covered       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Typhoon Name', 'Year', 'Region', 'Province', 'City/Municipality',
#        'Families', 'Person', 'Brgy', 'Dead', 'Injured/Ill', 'Missing',
#        'Totally', 'Partially', 'Total', 'Quantity', 'Cost', 'Nearest_Station',
#        'Station_Province', 'Distance_km', 'PAR_START', 'PAR_END',
#        'Duration_in_PAR_Hours', 'Max_Sustained_Wind_kph', 'Typhoon_Type',
#        'Max_24hr_Rainfall_mm', 'Total_Storm_Rainfall_mm', 'Min_Pressure_hPa',
#        'Weather_Station_Mapped', 'Weather_Records_Found',
#        'Weather_Days_Covered'],
#       dtype='object')

# %%
df.head()
# Out:
#   Typhoon Name  Year  Region Province City/Municipality  Families  Person  \
# 0        BETTY  2023       2  BATANES             BASCO      3608   11120
# 1        BETTY  2023       2  BATANES           ITBAYAT       968    3028
# 2        BETTY  2023       2  BATANES             IVANA       444    1532
# 3        BETTY  2023       2  BATANES           MAHATAO       575    1792
# 4        BETTY  2023       2  BATANES           SABTANG       575    1955
#
#    Brgy  Dead  Injured/Ill  ...   PAR_END  Duration_in_PAR_Hours  \
# 0     6     0            0  ...  6/1/2023                  133.0
# 1     5     0            0  ...  6/1/2023                  133.0
# 2     4     0            0  ...  6/1/2023                  133.0
# 3     4     0            0  ...  6/1/2023                  133.0
# 4     6     0            0  ...  6/1/2023                  133.0
#
#    Max_Sustained_Wind_kph  Typhoon_Type  Max_24hr_Rainfall_mm  \
# 0                     195           STY                  25.6
# 1                     195           STY                  20.3
# 2                     195           STY                  25.6
# 3                     195           STY                  25.6
# 4                     195           STY                  25.6
#
#    Total_Storm_Rainfall_mm Min_Pressure_hPa Weather_Station_Mapped  \
# 0                    39.00            977.1                      1
# 1                    32.71           1000.5                      1
# 2                    39.00            977.1                      1
# 3                    39.00            977.1                      1
# 4                    39.00            977.1                      1
#
#    Weather_Records_Found Weather_Days_Covered
# 0                      6                    6
# 1                      6                    6
# 2                      6                    6
# 3                      6                    6
# 4                      6                    6
#
# [5 rows x 30 columns]

# %%
df.drop(columns=['Quantity', 'PAR_START', 'PAR_END', 'Weather_Days_Covered', 'Total', 'Weather_Station_Mapped', 'Station_Province', 'Nearest_Station', 'Year', 'Typhoon Name', 'City/Municipality', 'Province', 'Distance_km'], inplace=True)
df.head()
# Out:
#    Region  Families  Person  Brgy  Dead  Injured/Ill  Missing  Totally  \
# 0       2      3608   11120     6     0            0        0        0
# 1       2       968    3028     5     0            0        0        0
# 2       2       444    1532     4     0            0        0        0
# 3       2       575    1792     4     0            0        0        0
# 4       2       575    1955     6     0            0        0        0
#
#    Partially        Cost  Duration_in_PAR_Hours  Max_Sustained_Wind_kph  \
# 0          0  2646179.36                  133.0                     195
# 1          0   494592.00                  133.0                     195
# 2          0   227328.00                  133.0                     195
# 3          0   291082.96                  133.0                     195
# 4          0   296521.75                  133.0                     195
#
#   Typhoon_Type  Max_24hr_Rainfall_mm  Total_Storm_Rainfall_mm  \
# 0          STY                  25.6                    39.00
# 1          STY                  20.3                    32.71
# 2          STY                  25.6                    39.00
# 3          STY                  25.6                    39.00
# 4          STY                  25.6                    39.00
#
#    Min_Pressure_hPa  Weather_Records_Found
# 0             977.1                      6
# 1            1000.5                      6
# 2             977.1                      6
# 3             977.1                      6
# 4             977.1                      6

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['region', 'families', 'person', 'brgy', 'dead', 'injured/ill',
#        'missing', 'totally', 'partially', 'cost', 'duration_in_par_hours',
#        'max_sustained_wind_kph', 'typhoon_type', 'max_24hr_rainfall_mm',
#        'total_storm_rainfall_mm', 'min_pressure_hpa', 'weather_records_found'],
#       dtype='object')

# %%
df['typhoon_type'].unique()
# Out:
# array(['STY', 'TY', 'STS', 'TD', 'TS'], dtype=object)

# %% [markdown]
# ## Data Transformation

# %%
# Convert 'region' column to object type
df['region'] = df['region'].astype('object')

# Perform one-hot encoding for 'region' and convert to int (0/1)
region_encoded = pd.get_dummies(df['region'], prefix='region').astype(int)

# Map 'typhoon_type' to the specified labels
typhoon_type_mapping = {'STY': 4, 'TY': 3, 'STS': 2, 'TD': 1, 'TS': 0}
df['typhoon_type'] = df['typhoon_type'].map(typhoon_type_mapping)

# Concatenate the one-hot encoded 'region' columns back to the dataframe
df = pd.concat([df, region_encoded], axis=1)

# Drop the original 'region' column as it's now encoded
df.drop(columns=['region'], inplace=True)

df.head()
# Out:
#    families  person  brgy  dead  injured/ill  missing  totally  partially  \
# 0      3608   11120     6     0            0        0        0          0
# 1       968    3028     5     0            0        0        0          0
# 2       444    1532     4     0            0        0        0          0
# 3       575    1792     4     0            0        0        0          0
# 4       575    1955     6     0            0        0        0          0
#
#          cost  duration_in_par_hours  max_sustained_wind_kph  typhoon_type  \
# 0  2646179.36                  133.0                     195             4
# 1   494592.00                  133.0                     195             4
# 2   227328.00                  133.0                     195             4
# 3   291082.96                  133.0                     195             4
# 4   296521.75                  133.0                     195             4
#
#    max_24hr_rainfall_mm  total_storm_rainfall_mm  min_pressure_hpa  \
# 0                  25.6                    39.00             977.1
# 1                  20.3                    32.71            1000.5
# 2                  25.6                    39.00             977.1
# 3                  25.6                    39.00             977.1
# 4                  25.6                    39.00             977.1
#
#    weather_records_found  region_2  region_3  region_5  region_8
# 0                      6         1         0         0         0
# 1                      6         1         0         0         0
# 2                      6         1         0         0         0
# 3                      6         1         0         0         0
# 4                      6         1         0         0         0

# %% [markdown]
# ## PCA Generalization Functions
# Functions for performing Principal Component Analysis on the typhoon impact dataset.

# %%
def prepare_pca_features(input_dataframe: pd.DataFrame, categorical_columns: list = None) -> tuple:
    """
    Prepare features for PCA by separating numerical and categorical columns.
    
    Parameters:
    -----------
    input_dataframe : pd.DataFrame
        The input dataframe containing features
    categorical_columns : list, optional
        List of categorical column names. If None, auto-detects object dtype columns.
    
    Returns:
    --------
    tuple: (numerical_features_df, categorical_features_df, numerical_column_names)
    """
    if categorical_columns is None:
        categorical_columns = input_dataframe.select_dtypes(include=['object']).columns.tolist()
    
    numerical_column_names = [col for col in input_dataframe.columns if col not in categorical_columns]
    
    numerical_features_df = input_dataframe[numerical_column_names].copy()
    categorical_features_df = input_dataframe[categorical_columns].copy() if categorical_columns else pd.DataFrame()
    
    return numerical_features_df, categorical_features_df, numerical_column_names


def scale_numerical_features(numerical_features_df: pd.DataFrame) -> tuple:
    """
    Scale numerical features using StandardScaler.
    
    Parameters:
    -----------
    numerical_features_df : pd.DataFrame
        DataFrame containing only numerical features
    
    Returns:
    --------
    tuple: (scaled_features_array, fitted_scaler_object)
    """
    feature_scaler_object = StandardScaler()
    scaled_features_array = feature_scaler_object.fit_transform(numerical_features_df)
    
    return scaled_features_array, feature_scaler_object


def perform_pca_analysis(
    scaled_features_array: np.ndarray,
    n_components: int = None,
    variance_threshold: float = 0.95
) -> tuple:
    """
    Perform PCA analysis on scaled features.
    
    Parameters:
    -----------
    scaled_features_array : np.ndarray
        Scaled numerical features array
    n_components : int, optional
        Number of components to keep. If None, uses variance_threshold.
    variance_threshold : float, default=0.95
        Cumulative variance threshold to determine n_components if n_components is None.
    
    Returns:
    --------
    tuple: (pca_transformed_array, fitted_pca_object, explained_variance_ratios)
    """
    # First fit PCA to determine optimal components if not specified
    if n_components is None:
        preliminary_pca_object = PCA()
        preliminary_pca_object.fit(scaled_features_array)
        cumulative_variance_array = np.cumsum(preliminary_pca_object.explained_variance_ratio_)
        n_components = np.argmax(cumulative_variance_array >= variance_threshold) + 1
        del preliminary_pca_object  # Clean up to avoid memory leak
    
    # Perform final PCA with determined number of components
    final_pca_object = PCA(n_components=n_components)
    pca_transformed_array = final_pca_object.fit_transform(scaled_features_array)
    explained_variance_ratios = final_pca_object.explained_variance_ratio_
    
    return pca_transformed_array, final_pca_object, explained_variance_ratios


def create_pca_dataframe(
    pca_transformed_array: np.ndarray,
    n_components: int
) -> pd.DataFrame:
    """
    Create a DataFrame from PCA transformed array with proper column names.
    
    Parameters:
    -----------
    pca_transformed_array : np.ndarray
        Array of PCA transformed features
    n_components : int
        Number of PCA components
    
    Returns:
    --------
    pd.DataFrame: DataFrame with PCA components as columns
    """
    pca_column_names = [f'PC{i+1}' for i in range(n_components)]
    pca_features_df = pd.DataFrame(pca_transformed_array, columns=pca_column_names)
    
    return pca_features_df


def plot_pca_variance_explanation(
    fitted_pca_object: PCA,
    figure_title: str = 'PCA Variance Explanation'
) -> None:
    """
    Plot the explained variance ratio for each PCA component.
    
    Parameters:
    -----------
    fitted_pca_object : PCA
        Fitted PCA object
    figure_title : str
        Title for the plot
    """
    variance_ratios_array = fitted_pca_object.explained_variance_ratio_
    cumulative_variance_array = np.cumsum(variance_ratios_array)
    n_components_count = len(variance_ratios_array)
    
    pca_variance_fig, pca_variance_axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Individual variance plot
    pca_variance_axes[0].bar(range(1, n_components_count + 1), variance_ratios_array, alpha=0.7, color='steelblue')
    pca_variance_axes[0].set_xlabel('Principal Component')
    pca_variance_axes[0].set_ylabel('Explained Variance Ratio')
    pca_variance_axes[0].set_title('Individual Explained Variance')
    pca_variance_axes[0].set_xticks(range(1, n_components_count + 1))
    
    # Cumulative variance plot
    pca_variance_axes[1].plot(range(1, n_components_count + 1), cumulative_variance_array, 'bo-', linewidth=2, markersize=8)
    pca_variance_axes[1].axhline(y=0.95, color='r', linestyle='--', label='95% Threshold')
    pca_variance_axes[1].set_xlabel('Number of Components')
    pca_variance_axes[1].set_ylabel('Cumulative Explained Variance')
    pca_variance_axes[1].set_title('Cumulative Explained Variance')
    pca_variance_axes[1].set_xticks(range(1, n_components_count + 1))
    pca_variance_axes[1].legend()
    pca_variance_axes[1].grid(True, alpha=0.3)
    
    pca_variance_fig.suptitle(figure_title, fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()
    
    # Clean up
    plt.close(pca_variance_fig)


def get_pca_feature_loadings(
    fitted_pca_object: PCA,
    feature_names_list: list
) -> pd.DataFrame:
    """
    Get the feature loadings (component weights) for each PCA component.
    
    Parameters:
    -----------
    fitted_pca_object : PCA
        Fitted PCA object
    feature_names_list : list
        List of original feature names
    
    Returns:
    --------
    pd.DataFrame: DataFrame with feature loadings for each component
    """
    n_components_count = fitted_pca_object.n_components_
    component_names_list = [f'PC{i+1}' for i in range(n_components_count)]
    
    feature_loadings_df = pd.DataFrame(
        fitted_pca_object.components_.T,
        columns=component_names_list,
        index=feature_names_list
    )
    
    return feature_loadings_df


def run_complete_pca_pipeline(
    input_dataframe: pd.DataFrame,
    n_components: int = None,
    variance_threshold: float = 0.95,
    categorical_columns: list = None,
    show_plots: bool = True,
    return_loadings: bool = True
) -> dict:
    """
    Run the complete PCA pipeline on the input dataframe.
    
    Parameters:
    -----------
    input_dataframe : pd.DataFrame
        Input dataframe with features
    n_components : int, optional
        Number of PCA components. If None, auto-determined by variance_threshold.
    variance_threshold : float, default=0.95
        Cumulative variance threshold for auto-determining n_components
    categorical_columns : list, optional
        List of categorical column names to exclude from PCA
    show_plots : bool, default=True
        Whether to display variance explanation plots
    return_loadings : bool, default=True
        Whether to include feature loadings in the result
    
    Returns:
    --------
    dict: Dictionary containing:
        - 'pca_dataframe': DataFrame with PCA components
        - 'pca_object': Fitted PCA object
        - 'scaler_object': Fitted StandardScaler object
        - 'explained_variance': Array of explained variance ratios
        - 'total_variance_explained': Total variance explained by components
        - 'feature_loadings': DataFrame of feature loadings (if return_loadings=True)
        - 'numerical_features': List of numerical feature names used
    """
    # Step 1: Prepare features
    numerical_features_df, categorical_features_df, numerical_column_names = prepare_pca_features(
        input_dataframe, categorical_columns
    )
    
    print(f"Numerical features for PCA: {len(numerical_column_names)}")
    print(f"Features: {numerical_column_names}")
    
    # Step 2: Scale features
    scaled_features_array, feature_scaler_object = scale_numerical_features(numerical_features_df)
    
    # Step 3: Perform PCA
    pca_transformed_array, fitted_pca_object, explained_variance_ratios = perform_pca_analysis(
        scaled_features_array, n_components, variance_threshold
    )
    
    actual_n_components = fitted_pca_object.n_components_
    total_variance_explained = np.sum(explained_variance_ratios)
    
    print(f"\nPCA Results:")
    print(f"Number of components: {actual_n_components}")
    print(f"Total variance explained: {total_variance_explained:.4f} ({total_variance_explained*100:.2f}%)")
    
    # Step 4: Create PCA DataFrame
    pca_features_df = create_pca_dataframe(pca_transformed_array, actual_n_components)
    
    # Step 5: Plot variance explanation
    if show_plots:
        plot_pca_variance_explanation(fitted_pca_object, 'Typhoon Impact Data - PCA Variance Explanation')
    
    # Prepare result dictionary
    pca_result_dict = {
        'pca_dataframe': pca_features_df,
        'pca_object': fitted_pca_object,
        'scaler_object': feature_scaler_object,
        'explained_variance': explained_variance_ratios,
        'total_variance_explained': total_variance_explained,
        'numerical_features': numerical_column_names
    }
    
    # Step 6: Get feature loadings if requested
    if return_loadings:
        feature_loadings_df = get_pca_feature_loadings(fitted_pca_object, numerical_column_names)
        pca_result_dict['feature_loadings'] = feature_loadings_df
    
    # Clean up intermediate variables
    del scaled_features_array, pca_transformed_array
    
    return pca_result_dict

# %%
# Run PCA pipeline on typhoon impact data
typhoon_pca_results = run_complete_pca_pipeline(
    input_dataframe=df,
    n_components=None,  # Auto-determine based on variance threshold
    variance_threshold=0.95,
    categorical_columns=None,  # Include all columns (typhoon_type is now ordinal encoded)
    show_plots=True,
    return_loadings=True
)
# Out:
# Numerical features for PCA: 20
# Features: ['families', 'person', 'brgy', 'dead', 'injured/ill', 'missing', 'totally', 'partially', 'cost', 'duration_in_par_hours', 'max_sustained_wind_kph', 'typhoon_type', 'max_24hr_rainfall_mm', 'total_storm_rainfall_mm', 'min_pressure_hpa', 'weather_records_found', 'region_2', 'region_3', 'region_5', 'region_8']
#
# PCA Results:
# Number of components: 13
# Total variance explained: 0.9502 (95.02%)

# %%
# Access PCA results
typhoon_pca_df = typhoon_pca_results['pca_dataframe']

# Display explained variance information
print("=" * 60)
print("PCA EXPLAINED VARIANCE SUMMARY")
print("=" * 60)
print(f"Total samples: {len(typhoon_pca_df)}")
print(f"Number of PCA components: {typhoon_pca_df.shape[1]}")
print(f"Total variance explained: {typhoon_pca_results['total_variance_explained']*100:.2f}%")
print("\nVariance explained per component:")
for i, var in enumerate(typhoon_pca_results['explained_variance']):
    print(f"  PC{i+1}: {var*100:.2f}%")
print("=" * 60)
# Out:
# ============================================================
# PCA EXPLAINED VARIANCE SUMMARY
# ============================================================
# Total samples: 1776
# Number of PCA components: 13
# Total variance explained: 95.02%
#
# Variance explained per component:
#   PC1: 19.58%
#   PC2: 11.76%
#   PC3: 10.22%
#   PC4: 9.50%
#   PC5: 7.59%
#   PC6: 6.65%
#   PC7: 5.90%
#   PC8: 5.62%
#   PC9: 4.56%
#   PC10: 4.43%
#   PC11: 3.79%
#   PC12: 2.97%
#   PC13: 2.45%
# ============================================================

# %% [markdown]
# ## Plotting 2D and 3D

# %%
# 3D PCA Visualization
from mpl_toolkits.mplot3d import Axes3D

def plot_pca_3d(
    pca_dataframe: pd.DataFrame,
    cluster_labels: np.ndarray = None,
    figure_title: str = 'PCA 3D Visualization'
) -> None:
    """
    Create a 3D scatter plot of the first 3 PCA components.
    
    Parameters:
    -----------
    pca_dataframe : pd.DataFrame
        DataFrame containing PCA components (PC1, PC2, PC3)
    cluster_labels : np.ndarray, optional
        Cluster labels for coloring points
    figure_title : str
        Title for the 3D plot
    """
    pca_3d_fig = plt.figure(figsize=(12, 10))
    pca_3d_ax = pca_3d_fig.add_subplot(111, projection='3d')
    
    pc1_values = pca_dataframe['PC1'].values
    pc2_values = pca_dataframe['PC2'].values
    pc3_values = pca_dataframe['PC3'].values
    
    if cluster_labels is not None:
        scatter_plot = pca_3d_ax.scatter(
            pc1_values, pc2_values, pc3_values,
            c=cluster_labels, cmap='viridis', s=50, alpha=0.7
        )
        pca_3d_fig.colorbar(scatter_plot, ax=pca_3d_ax, label='Cluster')
    else:
        pca_3d_ax.scatter(
            pc1_values, pc2_values, pc3_values,
            c='steelblue', s=50, alpha=0.7
        )
    
    pca_3d_ax.set_xlabel('PC1')
    pca_3d_ax.set_ylabel('PC2')
    pca_3d_ax.set_zlabel('PC3')
    pca_3d_ax.set_title(figure_title, fontsize=14, fontweight='bold')
    
    plt.tight_layout()
    plt.show()
    plt.close(pca_3d_fig)

# Plot 3D PCA visualization
plot_pca_3d(typhoon_pca_df, figure_title='Typhoon Impact Data - 3D PCA Visualization')

# %%
# 2D PCA Visualization
def plot_pca_2d(
    pca_dataframe: pd.DataFrame,
    cluster_labels: np.ndarray = None,
    figure_title: str = 'PCA 2D Visualization'
) -> None:
    """
    Create a 2D scatter plot of the first 2 PCA components.
    
    Parameters:
    -----------
    pca_dataframe : pd.DataFrame
        DataFrame containing PCA components (PC1, PC2)
    cluster_labels : np.ndarray, optional
        Cluster labels for coloring points
    figure_title : str
        Title for the 2D plot
    """
    pca_2d_fig, pca_2d_ax = plt.subplots(figsize=(12, 10))
    
    pc1_values = pca_dataframe['PC1'].values
    pc2_values = pca_dataframe['PC2'].values
    
    if cluster_labels is not None:
        scatter_plot_2d = pca_2d_ax.scatter(
            pc1_values, pc2_values,
            c=cluster_labels, cmap='viridis', s=50, alpha=0.7
        )
        pca_2d_fig.colorbar(scatter_plot_2d, ax=pca_2d_ax, label='Cluster')
    else:
        pca_2d_ax.scatter(
            pc1_values, pc2_values,
            c='steelblue', s=50, alpha=0.7
        )
    
    pca_2d_ax.set_xlabel('PC1')
    pca_2d_ax.set_ylabel('PC2')
    pca_2d_ax.set_title(figure_title, fontsize=14, fontweight='bold')
    pca_2d_ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    plt.close(pca_2d_fig)

# Plot 2D PCA visualization
plot_pca_2d(typhoon_pca_df, figure_title='Typhoon Impact Data - 2D PCA Visualization')

# %%
df.head()
# Out:
#    families  person  brgy  dead  injured/ill  missing  totally  partially  \
# 0      3608   11120     6     0            0        0        0          0
# 1       968    3028     5     0            0        0        0          0
# 2       444    1532     4     0            0        0        0          0
# 3       575    1792     4     0            0        0        0          0
# 4       575    1955     6     0            0        0        0          0
#
#          cost  duration_in_par_hours  max_sustained_wind_kph  typhoon_type  \
# 0  2646179.36                  133.0                     195             4
# 1   494592.00                  133.0                     195             4
# 2   227328.00                  133.0                     195             4
# 3   291082.96                  133.0                     195             4
# 4   296521.75                  133.0                     195             4
#
#    max_24hr_rainfall_mm  total_storm_rainfall_mm  min_pressure_hpa  \
# 0                  25.6                    39.00             977.1
# 1                  20.3                    32.71            1000.5
# 2                  25.6                    39.00             977.1
# 3                  25.6                    39.00             977.1
# 4                  25.6                    39.00             977.1
#
#    weather_records_found  region_2  region_3  region_5  region_8
# 0                      6         1         0         0         0
# 1                      6         1         0         0         0
# 2                      6         1         0         0         0
# 3                      6         1         0         0         0
# 4                      6         1         0         0         0

# %% [markdown]
# ## Standard Scaling of Sample Data

# %%
# Initialize StandardScaler
scaler = StandardScaler()

df_clean = df.copy()

# Fit and transform the data
df_scaled = scaler.fit_transform(df_clean)

# Convert back to DataFrame with original column names
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)

print("Original data (first 5 rows):")
display(df.head())
print("\nScaled data (first 5 rows):")
display(df_scaled.head())
# Out:
# Original data (first 5 rows):
#    families  person  brgy  dead  injured/ill  missing  totally  partially  \
# 0      3608   11120     6     0            0        0        0          0
# 1       968    3028     5     0            0        0        0          0
# 2       444    1532     4     0            0        0        0          0
# 3       575    1792     4     0            0        0        0          0
# 4       575    1955     6     0            0        0        0          0
#
#          cost  duration_in_par_hours  max_sustained_wind_kph  typhoon_type  \
# 0  2646179.36                  133.0                     195             4
# 1   494592.00                  133.0                     195             4
# 2   227328.00                  133.0                     195             4
# 3   291082.96                  133.0                     195             4
# 4   296521.75                  133.0                     195             4
#
#    max_24hr_rainfall_mm  total_storm_rainfall_mm  min_pressure_hpa  \
# 0                  25.6                    39.00             977.1
# 1                  20.3                    32.71            1000.5
# 2                  25.6                    39.00             977.1
# 3                  25.6                    39.00             977.1
# 4                  25.6                    39.00             977.1
#
#    weather_records_found  region_2  region_3  region_5  region_8
# 0                      6         1         0         0         0
# 1                      6         1         0         0         0
# 2                      6         1         0         0         0
# 3                      6         1         0         0         0
# 4                      6         1         0         0         0
# Scaled data (first 5 rows):
#    families    person      brgy     dead  injured/ill   missing   totally  \
# 0  0.627959  0.432912 -0.245512 -0.04519    -0.121532 -0.050655 -0.140446
# 1 -0.096344 -0.147600 -0.332928 -0.04519    -0.121532 -0.050655 -0.140446
# 2 -0.240108 -0.254921 -0.420344 -0.04519    -0.121532 -0.050655 -0.140446
# 3 -0.204167 -0.236269 -0.420344 -0.04519    -0.121532 -0.050655 -0.140446
# 4 -0.204167 -0.224576 -0.245512 -0.04519    -0.121532 -0.050655 -0.140446
#
#    partially      cost  duration_in_par_hours  max_sustained_wind_kph  \
# 0  -0.198449  1.833588               0.422971                1.093216
# 1  -0.198449  0.147222               0.422971                1.093216
# 2  -0.198449 -0.062254               0.422971                1.093216
# 3  -0.198449 -0.012284               0.422971                1.093216
# 4  -0.198449 -0.008021               0.422971                1.093216
#
#    typhoon_type  max_24hr_rainfall_mm  total_storm_rainfall_mm  \
# 0      1.133352             -1.099347                -1.169851
# 1      1.133352             -1.173803                -1.226523
# 2      1.133352             -1.099347                -1.169851
# 3      1.133352             -1.099347                -1.169851
# 4      1.133352             -1.099347                -1.169851
#
#    min_pressure_hpa  weather_records_found  region_2  region_3  region_5  \
# 0         -1.861117               0.309408  2.161972 -0.557406 -0.776459
# 1          0.466233               0.309408  2.161972 -0.557406 -0.776459
# 2         -1.861117               0.309408  2.161972 -0.557406 -0.776459
# 3         -1.861117               0.309408  2.161972 -0.557406 -0.776459
# 4         -1.861117               0.309408  2.161972 -0.557406 -0.776459
#
#    region_8
# 0  -0.51649
# 1  -0.51649
# 2  -0.51649
# 3  -0.51649
# 4  -0.51649

# %%
# DBSCAN with Optuna Optimization (strictly 3 clusters)
from sklearn.cluster import DBSCAN
import numpy as np

def optuna_dbscan_objective(trial, data):
    """Optuna objective for DBSCAN optimization with strict 3 clusters constraint."""
    eps = trial.suggest_float('eps', 0.5, 10.0)
    min_samples = trial.suggest_int('min_samples', 2, 20)
    
    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    labels = dbscan.fit_predict(data)
    
    # Count clusters (excluding noise points labeled as -1)
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    
    # Strictly enforce 3 clusters - return very low score otherwise
    if n_clusters != 3:
        return -1.0
    
    # Filter out noise points for metric calculation
    valid_mask = labels >= 0
    valid_data = data[valid_mask]
    valid_labels = labels[valid_mask]
    
    # Penalize if too many noise points (more than 10%)
    noise_ratio = np.sum(labels == -1) / len(labels)
    if noise_ratio > 0.10:
        return -1.0
    
    if len(np.unique(valid_labels)) < 2:
        return -1.0
    
    # Return silhouette score as the objective
    return silhouette_score(valid_data, valid_labels)

# Run Optuna optimization for DBSCAN
print("Running Optuna optimization for DBSCAN (strictly 3 clusters)...")
print("This may take a moment as we search for parameters that produce exactly 3 clusters.\n")

dbscan_study = optuna.create_study(direction='maximize', study_name='dbscan_3clusters_optimization')
dbscan_study.optimize(
    lambda trial: optuna_dbscan_objective(trial, df_scaled.values),
    n_trials=200,  # More trials to find valid 3-cluster configurations
    show_progress_bar=True
)

# Get best parameters
best_params = dbscan_study.best_params
best_score = dbscan_study.best_value

print(f"\nBest parameters found:")
print(f"  - eps: {best_params['eps']:.4f}")
print(f"  - min_samples: {best_params['min_samples']}")
print(f"  - Best Silhouette Score: {best_score:.4f}")

# Train final DBSCAN model with best parameters
dbscan = DBSCAN(eps=best_params['eps'], min_samples=best_params['min_samples'])
dbscan_labels = dbscan.fit_predict(df_scaled)

# Verify cluster count
n_clusters = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
n_noise = list(dbscan_labels).count(-1)

print(f"\nFinal DBSCAN Results:")
print(f"  - Number of clusters: {n_clusters}")
print(f"  - Noise points: {n_noise} ({n_noise/len(dbscan_labels)*100:.2f}%)")

# Add cluster labels to dataframe
df['dbscan_cluster'] = dbscan_labels

# Calculate clustering metrics (excluding noise)
valid_mask = dbscan_labels >= 0
if np.sum(valid_mask) > 0 and len(np.unique(dbscan_labels[valid_mask])) >= 2:
    silhouette = silhouette_score(df_scaled.values[valid_mask], dbscan_labels[valid_mask])
    calinski = calinski_harabasz_score(df_scaled.values[valid_mask], dbscan_labels[valid_mask])
    davies = davies_bouldin_score(df_scaled.values[valid_mask], dbscan_labels[valid_mask])
    
    print(f"\nClustering Metrics (excluding noise points):")
    print(f"  - Silhouette Score: {silhouette:.4f}")
    print(f"  - Calinski-Harabasz Index: {calinski:.4f}")
    print(f"  - Davies-Bouldin Index: {davies:.4f}")
# Out:
# [I 2025-12-10 19:05:31,724] A new study created in memory with name: dbscan_3clusters_optimization
# Running Optuna optimization for DBSCAN (strictly 3 clusters)...
# This may take a moment as we search for parameters that produce exactly 3 clusters.
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2025-12-10 19:05:32,019] Trial 0 finished with value: 0.5103783433899984 and parameters: {'eps': 6.233959192630316, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,147] Trial 1 finished with value: -1.0 and parameters: {'eps': 6.175827371844647, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,313] Trial 2 finished with value: 0.3983554727439596 and parameters: {'eps': 3.646477019480147, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,363] Trial 3 finished with value: -1.0 and parameters: {'eps': 1.3022607516315183, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,313] Trial 2 finished with value: 0.3983554727439596 and parameters: {'eps': 3.646477019480147, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,363] Trial 3 finished with value: -1.0 and parameters: {'eps': 1.3022607516315183, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,537] Trial 4 finished with value: 0.4676240729449076 and parameters: {'eps': 4.099973074934512, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,570] Trial 5 finished with value: -1.0 and parameters: {'eps': 2.9317536884639086, 'min_samples': 16}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,690] Trial 6 finished with value: -1.0 and parameters: {'eps': 8.896726881416317, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,730] Trial 7 finished with value: -1.0 and parameters: {'eps': 1.5929535669587838, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,537] Trial 4 finished with value: 0.4676240729449076 and parameters: {'eps': 4.099973074934512, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,570] Trial 5 finished with value: -1.0 and parameters: {'eps': 2.9317536884639086, 'min_samples': 16}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,690] Trial 6 finished with value: -1.0 and parameters: {'eps': 8.896726881416317, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,730] Trial 7 finished with value: -1.0 and parameters: {'eps': 1.5929535669587838, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,864] Trial 8 finished with value: -1.0 and parameters: {'eps': 9.403970922287687, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,998] Trial 9 finished with value: -1.0 and parameters: {'eps': 9.375855991963604, 'min_samples': 20}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,864] Trial 8 finished with value: -1.0 and parameters: {'eps': 9.403970922287687, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:32,998] Trial 9 finished with value: -1.0 and parameters: {'eps': 9.375855991963604, 'min_samples': 20}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,137] Trial 10 finished with value: -1.0 and parameters: {'eps': 6.656868601794884, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,269] Trial 11 finished with value: -1.0 and parameters: {'eps': 4.458611654345178, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,137] Trial 10 finished with value: -1.0 and parameters: {'eps': 6.656868601794884, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,269] Trial 11 finished with value: -1.0 and parameters: {'eps': 4.458611654345178, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,447] Trial 12 finished with value: -1.0 and parameters: {'eps': 7.055977191140984, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,535] Trial 13 finished with value: -1.0 and parameters: {'eps': 5.303362536180443, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,447] Trial 12 finished with value: -1.0 and parameters: {'eps': 7.055977191140984, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,535] Trial 13 finished with value: -1.0 and parameters: {'eps': 5.303362536180443, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,713] Trial 14 finished with value: -1.0 and parameters: {'eps': 8.037270709166606, 'min_samples': 14}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,823] Trial 15 finished with value: -1.0 and parameters: {'eps': 5.180370611101611, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,855] Trial 16 finished with value: -1.0 and parameters: {'eps': 2.854170160842167, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,713] Trial 14 finished with value: -1.0 and parameters: {'eps': 8.037270709166606, 'min_samples': 14}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,823] Trial 15 finished with value: -1.0 and parameters: {'eps': 5.180370611101611, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,855] Trial 16 finished with value: -1.0 and parameters: {'eps': 2.854170160842167, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,966] Trial 17 finished with value: -1.0 and parameters: {'eps': 7.643019546941911, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,165] Trial 18 finished with value: 0.4826957280285636 and parameters: {'eps': 5.65534355673739, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:33,966] Trial 17 finished with value: -1.0 and parameters: {'eps': 7.643019546941911, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,165] Trial 18 finished with value: 0.4826957280285636 and parameters: {'eps': 5.65534355673739, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,280] Trial 19 finished with value: -1.0 and parameters: {'eps': 5.851362341554681, 'min_samples': 13}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,280] Trial 19 finished with value: -1.0 and parameters: {'eps': 5.851362341554681, 'min_samples': 13}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,526] Trial 20 finished with value: -1.0 and parameters: {'eps': 8.290757903323334, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,603] Trial 21 finished with value: -1.0 and parameters: {'eps': 4.400915589323415, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,689] Trial 22 finished with value: -1.0 and parameters: {'eps': 4.299561178685437, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,526] Trial 20 finished with value: -1.0 and parameters: {'eps': 8.290757903323334, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,603] Trial 21 finished with value: -1.0 and parameters: {'eps': 4.400915589323415, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,689] Trial 22 finished with value: -1.0 and parameters: {'eps': 4.299561178685437, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,785] Trial 23 finished with value: -1.0 and parameters: {'eps': 5.416695785142577, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,919] Trial 24 finished with value: -1.0 and parameters: {'eps': 6.915739580540748, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,785] Trial 23 finished with value: -1.0 and parameters: {'eps': 5.416695785142577, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:34,919] Trial 24 finished with value: -1.0 and parameters: {'eps': 6.915739580540748, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,065] Trial 25 finished with value: -1.0 and parameters: {'eps': 2.761782071254363, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,104] Trial 26 finished with value: -1.0 and parameters: {'eps': 3.7510048728032355, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,192] Trial 27 finished with value: -1.0 and parameters: {'eps': 6.30082037667895, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,065] Trial 25 finished with value: -1.0 and parameters: {'eps': 2.761782071254363, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,104] Trial 26 finished with value: -1.0 and parameters: {'eps': 3.7510048728032355, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,192] Trial 27 finished with value: -1.0 and parameters: {'eps': 6.30082037667895, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,279] Trial 28 finished with value: -1.0 and parameters: {'eps': 4.972202027928879, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,392] Trial 29 finished with value: -1.0 and parameters: {'eps': 5.969761796817013, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,427] Trial 30 finished with value: -1.0 and parameters: {'eps': 1.9680942703744302, 'min_samples': 18}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,467] Trial 31 finished with value: -1.0 and parameters: {'eps': 3.530755525161539, 'min_samples': 13}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,279] Trial 28 finished with value: -1.0 and parameters: {'eps': 4.972202027928879, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,392] Trial 29 finished with value: -1.0 and parameters: {'eps': 5.969761796817013, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,427] Trial 30 finished with value: -1.0 and parameters: {'eps': 1.9680942703744302, 'min_samples': 18}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,467] Trial 31 finished with value: -1.0 and parameters: {'eps': 3.530755525161539, 'min_samples': 13}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,520] Trial 32 finished with value: -1.0 and parameters: {'eps': 3.704070988442007, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,541] Trial 33 finished with value: -1.0 and parameters: {'eps': 0.5039196490358844, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,618] Trial 34 finished with value: -1.0 and parameters: {'eps': 2.1512323421549757, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,520] Trial 32 finished with value: -1.0 and parameters: {'eps': 3.704070988442007, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,541] Trial 33 finished with value: -1.0 and parameters: {'eps': 0.5039196490358844, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,618] Trial 34 finished with value: -1.0 and parameters: {'eps': 2.1512323421549757, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,817] Trial 35 finished with value: -1.0 and parameters: {'eps': 4.845897187713698, 'min_samples': 16}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,863] Trial 36 finished with value: -1.0 and parameters: {'eps': 3.3245083128697455, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,967] Trial 37 finished with value: -1.0 and parameters: {'eps': 5.869457419732597, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,817] Trial 35 finished with value: -1.0 and parameters: {'eps': 4.845897187713698, 'min_samples': 16}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,863] Trial 36 finished with value: -1.0 and parameters: {'eps': 3.3245083128697455, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:35,967] Trial 37 finished with value: -1.0 and parameters: {'eps': 5.869457419732597, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,030] Trial 38 finished with value: -1.0 and parameters: {'eps': 4.11062073650982, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,164] Trial 39 finished with value: -1.0 and parameters: {'eps': 7.430246995642858, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,030] Trial 38 finished with value: -1.0 and parameters: {'eps': 4.11062073650982, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,164] Trial 39 finished with value: -1.0 and parameters: {'eps': 7.430246995642858, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,299] Trial 40 finished with value: -1.0 and parameters: {'eps': 6.52245024693449, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,404] Trial 41 finished with value: -1.0 and parameters: {'eps': 5.761130898806102, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,479] Trial 42 finished with value: -1.0 and parameters: {'eps': 4.7367765090662886, 'min_samples': 12}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,299] Trial 40 finished with value: -1.0 and parameters: {'eps': 6.52245024693449, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,404] Trial 41 finished with value: -1.0 and parameters: {'eps': 5.761130898806102, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,479] Trial 42 finished with value: -1.0 and parameters: {'eps': 4.7367765090662886, 'min_samples': 12}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,587] Trial 43 finished with value: -1.0 and parameters: {'eps': 6.318289592819887, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,704] Trial 44 finished with value: -1.0 and parameters: {'eps': 5.531355545137391, 'min_samples': 15}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,587] Trial 43 finished with value: -1.0 and parameters: {'eps': 6.318289592819887, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,704] Trial 44 finished with value: -1.0 and parameters: {'eps': 5.531355545137391, 'min_samples': 15}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,858] Trial 45 finished with value: -1.0 and parameters: {'eps': 7.232696770189811, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,020] Trial 46 finished with value: -1.0 and parameters: {'eps': 8.607206838400487, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,048] Trial 47 finished with value: -1.0 and parameters: {'eps': 3.130280663267254, 'min_samples': 12}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:36,858] Trial 45 finished with value: -1.0 and parameters: {'eps': 7.232696770189811, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,020] Trial 46 finished with value: -1.0 and parameters: {'eps': 8.607206838400487, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,048] Trial 47 finished with value: -1.0 and parameters: {'eps': 3.130280663267254, 'min_samples': 12}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,149] Trial 48 finished with value: -1.0 and parameters: {'eps': 6.814183792432108, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,191] Trial 49 finished with value: -1.0 and parameters: {'eps': 2.5794828234184526, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,249] Trial 50 finished with value: -1.0 and parameters: {'eps': 4.045849834076987, 'min_samples': 20}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,291] Trial 51 finished with value: -1.0 and parameters: {'eps': 1.0262757794062267, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,314] Trial 52 finished with value: -1.0 and parameters: {'eps': 1.4818170214269746, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,149] Trial 48 finished with value: -1.0 and parameters: {'eps': 6.814183792432108, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,191] Trial 49 finished with value: -1.0 and parameters: {'eps': 2.5794828234184526, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,249] Trial 50 finished with value: -1.0 and parameters: {'eps': 4.045849834076987, 'min_samples': 20}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,291] Trial 51 finished with value: -1.0 and parameters: {'eps': 1.0262757794062267, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,314] Trial 52 finished with value: -1.0 and parameters: {'eps': 1.4818170214269746, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,451] Trial 53 finished with value: -1.0 and parameters: {'eps': 7.730081432007084, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,549] Trial 54 finished with value: -1.0 and parameters: {'eps': 5.055933062032572, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,451] Trial 53 finished with value: -1.0 and parameters: {'eps': 7.730081432007084, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,549] Trial 54 finished with value: -1.0 and parameters: {'eps': 5.055933062032572, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,667] Trial 55 finished with value: -1.0 and parameters: {'eps': 5.300662243243498, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,802] Trial 56 finished with value: -1.0 and parameters: {'eps': 6.25584173587224, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,667] Trial 55 finished with value: -1.0 and parameters: {'eps': 5.300662243243498, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,802] Trial 56 finished with value: -1.0 and parameters: {'eps': 6.25584173587224, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,928] Trial 57 finished with value: -1.0 and parameters: {'eps': 4.598435297785817, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,988] Trial 58 finished with value: -1.0 and parameters: {'eps': 2.243565136378075, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,928] Trial 57 finished with value: -1.0 and parameters: {'eps': 4.598435297785817, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:37,988] Trial 58 finished with value: -1.0 and parameters: {'eps': 2.243565136378075, 'min_samples': 6}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,169] Trial 59 finished with value: -1.0 and parameters: {'eps': 9.090642876055234, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,317] Trial 60 finished with value: -1.0 and parameters: {'eps': 5.637850034114975, 'min_samples': 12}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,356] Trial 61 finished with value: -1.0 and parameters: {'eps': 1.5140510772684561, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,169] Trial 59 finished with value: -1.0 and parameters: {'eps': 9.090642876055234, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,317] Trial 60 finished with value: -1.0 and parameters: {'eps': 5.637850034114975, 'min_samples': 12}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,356] Trial 61 finished with value: -1.0 and parameters: {'eps': 1.5140510772684561, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,400] Trial 62 finished with value: -1.0 and parameters: {'eps': 2.8696338483316044, 'min_samples': 16}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,561] Trial 63 finished with value: -1.0 and parameters: {'eps': 9.982281528838044, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,400] Trial 62 finished with value: -1.0 and parameters: {'eps': 2.8696338483316044, 'min_samples': 16}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,561] Trial 63 finished with value: -1.0 and parameters: {'eps': 9.982281528838044, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,639] Trial 64 finished with value: -1.0 and parameters: {'eps': 4.026295600911192, 'min_samples': 18}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,690] Trial 65 finished with value: -1.0 and parameters: {'eps': 3.2494545010854043, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,733] Trial 66 finished with value: -1.0 and parameters: {'eps': 0.8852682003707617, 'min_samples': 18}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,639] Trial 64 finished with value: -1.0 and parameters: {'eps': 4.026295600911192, 'min_samples': 18}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,690] Trial 65 finished with value: -1.0 and parameters: {'eps': 3.2494545010854043, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,733] Trial 66 finished with value: -1.0 and parameters: {'eps': 0.8852682003707617, 'min_samples': 18}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,876] Trial 67 finished with value: -1.0 and parameters: {'eps': 6.037501704536258, 'min_samples': 14}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,963] Trial 68 finished with value: -1.0 and parameters: {'eps': 3.696863659851463, 'min_samples': 19}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,067] Trial 69 finished with value: -1.0 and parameters: {'eps': 4.2992666919776195, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,876] Trial 67 finished with value: -1.0 and parameters: {'eps': 6.037501704536258, 'min_samples': 14}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:38,963] Trial 68 finished with value: -1.0 and parameters: {'eps': 3.696863659851463, 'min_samples': 19}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,067] Trial 69 finished with value: -1.0 and parameters: {'eps': 4.2992666919776195, 'min_samples': 7}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,128] Trial 70 finished with value: -1.0 and parameters: {'eps': 2.3981369825342247, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,183] Trial 71 finished with value: -1.0 and parameters: {'eps': 1.9887454294452933, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,128] Trial 70 finished with value: -1.0 and parameters: {'eps': 2.3981369825342247, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,183] Trial 71 finished with value: -1.0 and parameters: {'eps': 1.9887454294452933, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,569] Trial 72 finished with value: -1.0 and parameters: {'eps': 8.293762372367183, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,721] Trial 73 finished with value: -1.0 and parameters: {'eps': 3.0918285967897763, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,569] Trial 72 finished with value: -1.0 and parameters: {'eps': 8.293762372367183, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,721] Trial 73 finished with value: -1.0 and parameters: {'eps': 3.0918285967897763, 'min_samples': 11}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,970] Trial 74 finished with value: -1.0 and parameters: {'eps': 6.7172118896175865, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,146] Trial 75 finished with value: -1.0 and parameters: {'eps': 5.216643699938656, 'min_samples': 13}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:39,970] Trial 74 finished with value: -1.0 and parameters: {'eps': 6.7172118896175865, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,146] Trial 75 finished with value: -1.0 and parameters: {'eps': 5.216643699938656, 'min_samples': 13}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,224] Trial 76 finished with value: -1.0 and parameters: {'eps': 3.454557981346683, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,267] Trial 77 finished with value: -1.0 and parameters: {'eps': 1.83508104464588, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,358] Trial 78 finished with value: -1.0 and parameters: {'eps': 4.527453356524548, 'min_samples': 12}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,224] Trial 76 finished with value: -1.0 and parameters: {'eps': 3.454557981346683, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,267] Trial 77 finished with value: -1.0 and parameters: {'eps': 1.83508104464588, 'min_samples': 8}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,358] Trial 78 finished with value: -1.0 and parameters: {'eps': 4.527453356524548, 'min_samples': 12}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,486] Trial 79 finished with value: -1.0 and parameters: {'eps': 7.099904005409599, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,557] Trial 80 finished with value: -1.0 and parameters: {'eps': 3.8638562232199716, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,605] Trial 81 finished with value: -1.0 and parameters: {'eps': 1.5370734649669342, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,645] Trial 82 finished with value: -1.0 and parameters: {'eps': 2.5630965717659917, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,486] Trial 79 finished with value: -1.0 and parameters: {'eps': 7.099904005409599, 'min_samples': 4}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,557] Trial 80 finished with value: -1.0 and parameters: {'eps': 3.8638562232199716, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,605] Trial 81 finished with value: -1.0 and parameters: {'eps': 1.5370734649669342, 'min_samples': 2}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,645] Trial 82 finished with value: -1.0 and parameters: {'eps': 2.5630965717659917, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,691] Trial 83 finished with value: -1.0 and parameters: {'eps': 1.2300875320106337, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,723] Trial 84 finished with value: -1.0 and parameters: {'eps': 0.9113556676380895, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,764] Trial 85 finished with value: -1.0 and parameters: {'eps': 0.5048120652422075, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,804] Trial 86 finished with value: -1.0 and parameters: {'eps': 2.8345956535069816, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,691] Trial 83 finished with value: -1.0 and parameters: {'eps': 1.2300875320106337, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,723] Trial 84 finished with value: -1.0 and parameters: {'eps': 0.9113556676380895, 'min_samples': 9}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,764] Trial 85 finished with value: -1.0 and parameters: {'eps': 0.5048120652422075, 'min_samples': 5}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,804] Trial 86 finished with value: -1.0 and parameters: {'eps': 2.8345956535069816, 'min_samples': 10}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,923] Trial 87 finished with value: -1.0 and parameters: {'eps': 4.869033900771578, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:40,923] Trial 87 finished with value: -1.0 and parameters: {'eps': 4.869033900771578, 'min_samples': 3}. Best is trial 0 with value: 0.5103783433899984.
# [I 2025-12-10 19:05:41,175] Trial 88 finished with value: 0.5117264001720476 and parameters: {'eps': 6.082851337424345, 'min_samples': 2}. Best is trial 88 with value: 0.5117264001720476.
# [I 2025-12-10 19:05:41,175] Trial 88 finished with value: 0.5117264001720476 and parameters: {'eps': 6.082851337424345, 'min_samples': 2}. Best is trial 88 with value: 0.5117264001720476.
# [I 2025-12-10 19:05:41,429] Trial 89 finished with value: 0.5115625502480284 and parameters: {'eps': 6.158362259298533, 'min_samples': 2}. Best is trial 88 with value: 0.5117264001720476.
# [I 2025-12-10 19:05:41,429] Trial 89 finished with value: 0.5115625502480284 and parameters: {'eps': 6.158362259298533, 'min_samples': 2}. Best is trial 88 with value: 0.5117264001720476.
# [I 2025-12-10 19:05:41,670] Trial 90 finished with value: 0.5103783433899984 and parameters: {'eps': 6.49104871076596, 'min_samples': 2}. Best is trial 88 with value: 0.5117264001720476.
# [I 2025-12-10 19:05:41,670] Trial 90 finished with value: 0.5103783433899984 and parameters: {'eps': 6.49104871076596, 'min_samples': 2}. Best is trial 88 with value: 0.5117264001720476.
# [I 2025-12-10 19:05:41,971] Trial 91 finished with value: 0.5117264001720476 and parameters: {'eps': 6.064373488873199, 'min_samples': 2}. Best is trial 88 with value: 0.5117264001720476.
# [I 2025-12-10 19:05:41,971] Trial 91 finished with value: 0.5117264001720476 and parameters: {'eps': 6.064373488873199, 'min_samples': 2}. Best is trial 88 with value: 0.5117264001720476.
# [I 2025-12-10 19:05:42,213] Trial 92 finished with value: 0.5121785212801023 and parameters: {'eps': 6.1494538891167725, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:42,354] Trial 93 finished with value: -1.0 and parameters: {'eps': 6.532391908148697, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:42,213] Trial 92 finished with value: 0.5121785212801023 and parameters: {'eps': 6.1494538891167725, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:42,354] Trial 93 finished with value: -1.0 and parameters: {'eps': 6.532391908148697, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:42,553] Trial 94 finished with value: 0.5117264001720476 and parameters: {'eps': 6.033729841802392, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:42,553] Trial 94 finished with value: 0.5117264001720476 and parameters: {'eps': 6.033729841802392, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:42,787] Trial 95 finished with value: 0.5103783433899984 and parameters: {'eps': 6.4520707096660335, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:42,787] Trial 95 finished with value: 0.5103783433899984 and parameters: {'eps': 6.4520707096660335, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:43,035] Trial 96 finished with value: 0.5117264001720476 and parameters: {'eps': 6.106807118497418, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:43,035] Trial 96 finished with value: 0.5117264001720476 and parameters: {'eps': 6.106807118497418, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:43,274] Trial 97 finished with value: 0.5103783433899984 and parameters: {'eps': 6.419744940148517, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:43,274] Trial 97 finished with value: 0.5103783433899984 and parameters: {'eps': 6.419744940148517, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:43,686] Trial 98 finished with value: 0.5103783433899984 and parameters: {'eps': 6.439541936014159, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:43,686] Trial 98 finished with value: 0.5103783433899984 and parameters: {'eps': 6.439541936014159, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:43,985] Trial 99 finished with value: 0.5117264001720476 and parameters: {'eps': 6.082192762083566, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:43,985] Trial 99 finished with value: 0.5117264001720476 and parameters: {'eps': 6.082192762083566, 'min_samples': 2}. Best is trial 92 with value: 0.5121785212801023.
# [I 2025-12-10 19:05:44,255] Trial 100 finished with value: 0.5127854592292372 and parameters: {'eps': 6.01852927312638, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:44,255] Trial 100 finished with value: 0.5127854592292372 and parameters: {'eps': 6.01852927312638, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:44,717] Trial 101 finished with value: 0.5117264001720476 and parameters: {'eps': 6.12229822442018, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:44,837] Trial 102 finished with value: -1.0 and parameters: {'eps': 6.077976486608608, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:44,717] Trial 101 finished with value: 0.5117264001720476 and parameters: {'eps': 6.12229822442018, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:44,837] Trial 102 finished with value: -1.0 and parameters: {'eps': 6.077976486608608, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:44,944] Trial 103 finished with value: -1.0 and parameters: {'eps': 5.828060169245195, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,054] Trial 104 finished with value: -1.0 and parameters: {'eps': 5.426912104476326, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:44,944] Trial 103 finished with value: -1.0 and parameters: {'eps': 5.828060169245195, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,054] Trial 104 finished with value: -1.0 and parameters: {'eps': 5.426912104476326, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,231] Trial 105 finished with value: -1.0 and parameters: {'eps': 6.949853743545496, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,373] Trial 106 finished with value: -1.0 and parameters: {'eps': 5.708203900832638, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,231] Trial 105 finished with value: -1.0 and parameters: {'eps': 6.949853743545496, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,373] Trial 106 finished with value: -1.0 and parameters: {'eps': 5.708203900832638, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,651] Trial 107 finished with value: 0.5110463110756072 and parameters: {'eps': 6.1930213248963195, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,651] Trial 107 finished with value: 0.5110463110756072 and parameters: {'eps': 6.1930213248963195, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,974] Trial 108 finished with value: 0.5110463110756072 and parameters: {'eps': 6.165961835897807, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,148] Trial 109 finished with value: -1.0 and parameters: {'eps': 6.165088395762224, 'min_samples': 4}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:45,974] Trial 108 finished with value: 0.5110463110756072 and parameters: {'eps': 6.165961835897807, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,148] Trial 109 finished with value: -1.0 and parameters: {'eps': 6.165088395762224, 'min_samples': 4}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,283] Trial 110 finished with value: -1.0 and parameters: {'eps': 5.896795990716041, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,445] Trial 111 finished with value: -1.0 and parameters: {'eps': 6.6890273015032555, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,283] Trial 110 finished with value: -1.0 and parameters: {'eps': 5.896795990716041, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,445] Trial 111 finished with value: -1.0 and parameters: {'eps': 6.6890273015032555, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,720] Trial 112 finished with value: 0.4836486427663079 and parameters: {'eps': 5.546346415910779, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,927] Trial 113 finished with value: 0.5110463110756072 and parameters: {'eps': 6.203722398656138, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,720] Trial 112 finished with value: 0.4836486427663079 and parameters: {'eps': 5.546346415910779, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:46,927] Trial 113 finished with value: 0.5110463110756072 and parameters: {'eps': 6.203722398656138, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,180] Trial 114 finished with value: 0.5110463110756072 and parameters: {'eps': 6.19290937639232, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,259] Trial 115 finished with value: -1.0 and parameters: {'eps': 6.001459057576398, 'min_samples': 4}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,350] Trial 116 finished with value: -1.0 and parameters: {'eps': 7.3802227112311956, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,180] Trial 114 finished with value: 0.5110463110756072 and parameters: {'eps': 6.19290937639232, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,259] Trial 115 finished with value: -1.0 and parameters: {'eps': 6.001459057576398, 'min_samples': 4}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,350] Trial 116 finished with value: -1.0 and parameters: {'eps': 7.3802227112311956, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,550] Trial 117 finished with value: 0.5103783433899984 and parameters: {'eps': 6.279468565284787, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,634] Trial 118 finished with value: -1.0 and parameters: {'eps': 6.832409172525087, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,550] Trial 117 finished with value: 0.5103783433899984 and parameters: {'eps': 6.279468565284787, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,634] Trial 118 finished with value: -1.0 and parameters: {'eps': 6.832409172525087, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,811] Trial 119 finished with value: 0.4826957280285636 and parameters: {'eps': 5.682834383301427, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,956] Trial 120 finished with value: -1.0 and parameters: {'eps': 5.470691722931139, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,811] Trial 119 finished with value: 0.4826957280285636 and parameters: {'eps': 5.682834383301427, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:47,956] Trial 120 finished with value: -1.0 and parameters: {'eps': 5.470691722931139, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,171] Trial 121 finished with value: -1.0 and parameters: {'eps': 6.125868694385198, 'min_samples': 4}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,171] Trial 121 finished with value: -1.0 and parameters: {'eps': 6.125868694385198, 'min_samples': 4}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,474] Trial 122 finished with value: 0.5110463110756072 and parameters: {'eps': 6.200851365925394, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,622] Trial 123 finished with value: -1.0 and parameters: {'eps': 5.927159867964953, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,474] Trial 122 finished with value: 0.5110463110756072 and parameters: {'eps': 6.200851365925394, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,622] Trial 123 finished with value: -1.0 and parameters: {'eps': 5.927159867964953, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,718] Trial 124 finished with value: -1.0 and parameters: {'eps': 5.094090664561197, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,861] Trial 125 finished with value: -1.0 and parameters: {'eps': 6.655203129020806, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,718] Trial 124 finished with value: -1.0 and parameters: {'eps': 5.094090664561197, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:48,861] Trial 125 finished with value: -1.0 and parameters: {'eps': 6.655203129020806, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:49,026] Trial 126 finished with value: -1.0 and parameters: {'eps': 5.7586158395020925, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:49,026] Trial 126 finished with value: -1.0 and parameters: {'eps': 5.7586158395020925, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:49,372] Trial 127 finished with value: 0.5103783433899984 and parameters: {'eps': 6.302905444114872, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:49,568] Trial 128 finished with value: -1.0 and parameters: {'eps': 7.003661752315791, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:49,372] Trial 127 finished with value: 0.5103783433899984 and parameters: {'eps': 6.302905444114872, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:49,568] Trial 128 finished with value: -1.0 and parameters: {'eps': 7.003661752315791, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:49,813] Trial 129 finished with value: -1.0 and parameters: {'eps': 6.02694251699095, 'min_samples': 4}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:49,813] Trial 129 finished with value: -1.0 and parameters: {'eps': 6.02694251699095, 'min_samples': 4}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:50,122] Trial 130 finished with value: -1.0 and parameters: {'eps': 6.576219150178699, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:50,122] Trial 130 finished with value: -1.0 and parameters: {'eps': 6.576219150178699, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:50,525] Trial 131 finished with value: 0.5103783433899984 and parameters: {'eps': 6.23439776029797, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:50,525] Trial 131 finished with value: 0.5103783433899984 and parameters: {'eps': 6.23439776029797, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:50,943] Trial 132 finished with value: 0.5121785212801023 and parameters: {'eps': 6.147567494233611, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:51,036] Trial 133 finished with value: -1.0 and parameters: {'eps': 5.370111231644044, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:51,140] Trial 134 finished with value: -1.0 and parameters: {'eps': 5.931626600999323, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:50,943] Trial 132 finished with value: 0.5121785212801023 and parameters: {'eps': 6.147567494233611, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:51,036] Trial 133 finished with value: -1.0 and parameters: {'eps': 5.370111231644044, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:51,140] Trial 134 finished with value: -1.0 and parameters: {'eps': 5.931626600999323, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:51,429] Trial 135 finished with value: 0.4826957280285636 and parameters: {'eps': 5.607452126328942, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# ...
# [I 2025-12-10 19:05:56,891] Trial 158 finished with value: -1.0 and parameters: {'eps': 5.810808910183823, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:57,133] Trial 159 finished with value: 0.4836486427663079 and parameters: {'eps': 5.555124966791366, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:57,133] Trial 159 finished with value: 0.4836486427663079 and parameters: {'eps': 5.555124966791366, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:57,382] Trial 160 finished with value: 0.5127854592292372 and parameters: {'eps': 6.010453514611298, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:57,382] Trial 160 finished with value: 0.5127854592292372 and parameters: {'eps': 6.010453514611298, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:57,642] Trial 161 finished with value: 0.5117264001720476 and parameters: {'eps': 6.060677343931019, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:57,757] Trial 162 finished with value: -1.0 and parameters: {'eps': 5.199447579374721, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:57,642] Trial 161 finished with value: 0.5117264001720476 and parameters: {'eps': 6.060677343931019, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:57,757] Trial 162 finished with value: -1.0 and parameters: {'eps': 5.199447579374721, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:58,016] Trial 163 finished with value: 0.5103783433899984 and parameters: {'eps': 6.392051263089322, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:58,016] Trial 163 finished with value: 0.5103783433899984 and parameters: {'eps': 6.392051263089322, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:58,351] Trial 164 finished with value: 0.5117264001720476 and parameters: {'eps': 6.062044863572728, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:58,351] Trial 164 finished with value: 0.5117264001720476 and parameters: {'eps': 6.062044863572728, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:58,563] Trial 165 finished with value: -1.0 and parameters: {'eps': 5.746143584789583, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:58,563] Trial 165 finished with value: -1.0 and parameters: {'eps': 5.746143584789583, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:58,900] Trial 166 finished with value: 0.5127854592292372 and parameters: {'eps': 5.979639703879884, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:58,900] Trial 166 finished with value: 0.5127854592292372 and parameters: {'eps': 5.979639703879884, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:59,152] Trial 167 finished with value: -1.0 and parameters: {'eps': 5.821465899901424, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:59,329] Trial 168 finished with value: -1.0 and parameters: {'eps': 6.545447177696938, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:59,152] Trial 167 finished with value: -1.0 and parameters: {'eps': 5.821465899901424, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:59,329] Trial 168 finished with value: -1.0 and parameters: {'eps': 6.545447177696938, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:59,598] Trial 169 finished with value: 0.4836486427663079 and parameters: {'eps': 5.53344271799732, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:59,598] Trial 169 finished with value: 0.4836486427663079 and parameters: {'eps': 5.53344271799732, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:59,899] Trial 170 finished with value: 0.5103783433899984 and parameters: {'eps': 6.304018140140144, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:05:59,899] Trial 170 finished with value: 0.5103783433899984 and parameters: {'eps': 6.304018140140144, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,244] Trial 171 finished with value: 0.5127854592292372 and parameters: {'eps': 5.95091655873087, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,244] Trial 171 finished with value: 0.5127854592292372 and parameters: {'eps': 5.95091655873087, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,509] Trial 172 finished with value: 0.5127854592292372 and parameters: {'eps': 5.977761705297632, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,631] Trial 173 finished with value: -1.0 and parameters: {'eps': 5.90625635163982, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,509] Trial 172 finished with value: 0.5127854592292372 and parameters: {'eps': 5.977761705297632, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,631] Trial 173 finished with value: -1.0 and parameters: {'eps': 5.90625635163982, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,775] Trial 174 finished with value: -1.0 and parameters: {'eps': 5.409289885616218, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,938] Trial 175 finished with value: -1.0 and parameters: {'eps': 5.7404194485853175, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,775] Trial 174 finished with value: -1.0 and parameters: {'eps': 5.409289885616218, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:00,938] Trial 175 finished with value: -1.0 and parameters: {'eps': 5.7404194485853175, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:01,381] Trial 176 finished with value: 0.5103783433899984 and parameters: {'eps': 6.348822922646371, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:01,493] Trial 177 finished with value: -1.0 and parameters: {'eps': 6.74336572068484, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:01,381] Trial 176 finished with value: 0.5103783433899984 and parameters: {'eps': 6.348822922646371, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:01,493] Trial 177 finished with value: -1.0 and parameters: {'eps': 6.74336572068484, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:02,010] Trial 178 finished with value: 0.5127854592292372 and parameters: {'eps': 5.985070788968943, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:02,010] Trial 178 finished with value: 0.5127854592292372 and parameters: {'eps': 5.985070788968943, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:02,446] Trial 179 finished with value: 0.4826957280285636 and parameters: {'eps': 5.631772339529447, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:02,558] Trial 180 finished with value: -1.0 and parameters: {'eps': 5.8901178725452015, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:02,446] Trial 179 finished with value: 0.4826957280285636 and parameters: {'eps': 5.631772339529447, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:02,558] Trial 180 finished with value: -1.0 and parameters: {'eps': 5.8901178725452015, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:02,861] Trial 181 finished with value: 0.5117264001720476 and parameters: {'eps': 6.030081196887965, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:02,861] Trial 181 finished with value: 0.5117264001720476 and parameters: {'eps': 6.030081196887965, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,077] Trial 182 finished with value: 0.5103783433899984 and parameters: {'eps': 6.22361088896747, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,077] Trial 182 finished with value: 0.5103783433899984 and parameters: {'eps': 6.22361088896747, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,334] Trial 183 finished with value: 0.5117264001720476 and parameters: {'eps': 6.025878525184188, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,546] Trial 184 finished with value: 0.5103783433899984 and parameters: {'eps': 6.40712174603111, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,334] Trial 183 finished with value: 0.5117264001720476 and parameters: {'eps': 6.025878525184188, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,546] Trial 184 finished with value: 0.5103783433899984 and parameters: {'eps': 6.40712174603111, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,831] Trial 185 finished with value: 0.5110463110756072 and parameters: {'eps': 6.20533557082683, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,909] Trial 186 finished with value: -1.0 and parameters: {'eps': 5.884815514449308, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,996] Trial 187 finished with value: -1.0 and parameters: {'eps': 6.5347737613972825, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,831] Trial 185 finished with value: 0.5110463110756072 and parameters: {'eps': 6.20533557082683, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,909] Trial 186 finished with value: -1.0 and parameters: {'eps': 5.884815514449308, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:03,996] Trial 187 finished with value: -1.0 and parameters: {'eps': 6.5347737613972825, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:04,206] Trial 188 finished with value: 0.4826957280285636 and parameters: {'eps': 5.647394989341254, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:04,319] Trial 189 finished with value: -1.0 and parameters: {'eps': 5.268138588994544, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:04,206] Trial 188 finished with value: 0.4826957280285636 and parameters: {'eps': 5.647394989341254, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:04,319] Trial 189 finished with value: -1.0 and parameters: {'eps': 5.268138588994544, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:04,575] Trial 190 finished with value: 0.5117264001720476 and parameters: {'eps': 6.087933574174119, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:04,575] Trial 190 finished with value: 0.5117264001720476 and parameters: {'eps': 6.087933574174119, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:04,786] Trial 191 finished with value: 0.5110463110756072 and parameters: {'eps': 6.180522372197986, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:04,786] Trial 191 finished with value: 0.5110463110756072 and parameters: {'eps': 6.180522372197986, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,145] Trial 192 finished with value: 0.5127854592292372 and parameters: {'eps': 5.969865726055964, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,252] Trial 193 finished with value: -1.0 and parameters: {'eps': 5.860407911085554, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,145] Trial 192 finished with value: 0.5127854592292372 and parameters: {'eps': 5.969865726055964, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,252] Trial 193 finished with value: -1.0 and parameters: {'eps': 5.860407911085554, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,484] Trial 194 finished with value: 0.5127854592292372 and parameters: {'eps': 5.986123413870769, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,576] Trial 195 finished with value: -1.0 and parameters: {'eps': 5.719575243563246, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,484] Trial 194 finished with value: 0.5127854592292372 and parameters: {'eps': 5.986123413870769, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,576] Trial 195 finished with value: -1.0 and parameters: {'eps': 5.719575243563246, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,762] Trial 196 finished with value: 0.5103783433899984 and parameters: {'eps': 6.2982188201255305, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,863] Trial 197 finished with value: -1.0 and parameters: {'eps': 5.469238812313622, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,762] Trial 196 finished with value: 0.5103783433899984 and parameters: {'eps': 6.2982188201255305, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:05,863] Trial 197 finished with value: -1.0 and parameters: {'eps': 5.469238812313622, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:06,096] Trial 198 finished with value: 0.5127854592292372 and parameters: {'eps': 5.956161788901317, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:06,206] Trial 199 finished with value: -1.0 and parameters: {'eps': 5.9456407559137086, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
#
# Best parameters found:
#   - eps: 6.0185
#   - min_samples: 2
#   - Best Silhouette Score: 0.5128
#
# Final DBSCAN Results:
#   - Number of clusters: 3
#   - Noise points: 22 (1.24%)
# [I 2025-12-10 19:06:06,096] Trial 198 finished with value: 0.5127854592292372 and parameters: {'eps': 5.956161788901317, 'min_samples': 2}. Best is trial 100 with value: 0.5127854592292372.
# [I 2025-12-10 19:06:06,206] Trial 199 finished with value: -1.0 and parameters: {'eps': 5.9456407559137086, 'min_samples': 3}. Best is trial 100 with value: 0.5127854592292372.
#
# Best parameters found:
#   - eps: 6.0185
#   - min_samples: 2
#   - Best Silhouette Score: 0.5128
#
# Final DBSCAN Results:
#   - Number of clusters: 3
#   - Noise points: 22 (1.24%)
#
# Clustering Metrics (excluding noise points):
#   - Silhouette Score: 0.5128
#   - Calinski-Harabasz Index: 31.0755
#   - Davies-Bouldin Index: 0.5928
#
# Clustering Metrics (excluding noise points):
#   - Silhouette Score: 0.5128
#   - Calinski-Harabasz Index: 31.0755
#   - Davies-Bouldin Index: 0.5928

# %%
# 3D visualization of DBSCAN clusters
plot_pca_3d(
    pca_dataframe=typhoon_pca_df,
    cluster_labels=dbscan_labels,
    figure_title='DBSCAN Clustering (eps=3.3) - 3D PCA Visualization'
)

# 2D visualization of DBSCAN clusters
plot_pca_2d(
    pca_dataframe=typhoon_pca_df,
    cluster_labels=dbscan_labels,
    figure_title='DBSCAN Clustering (eps=3.3) - 2D PCA Visualization'
)

# Load original data for readable representation
original_df = pd.read_csv('data/typhoon_impact_with_extreme_weather.csv')

# Add cluster labels to original data
original_df['dbscan_cluster'] = dbscan_labels

# Display data for each cluster (excluding noise points -1, showing only clusters 0, 1, 2)
print("\n" + "=" * 80)
print("DBSCAN CLUSTERING RESULTS (eps=3.3) - ORIGINAL DATA")
print("=" * 80)

for cluster_id in [0, 1, 2]:
    cluster_data = original_df[original_df['dbscan_cluster'] == cluster_id]
    
    print("\n" + "=" * 80)
    print(f"CLUSTER {cluster_id}")
    print(f"Number of records: {len(cluster_data)}")
    print("=" * 80)
    display(cluster_data.drop(columns=['dbscan_cluster']).head(10))

# Show noise points separately
noise_data = original_df[original_df['dbscan_cluster'] == -1]
print("\n" + "=" * 80)
print(f"NOISE POINTS (Cluster -1)")
print(f"Number of records: {len(noise_data)}")
print("=" * 80)
display(noise_data.drop(columns=['dbscan_cluster']).head(10))

# Summary statistics for each cluster
print("\n" + "=" * 80)
print("CLUSTER SUMMARY")
print("=" * 80)
for cluster_id in [-1, 0, 1, 2]:
    cluster_name = f"Cluster {cluster_id}" if cluster_id != -1 else "Noise"
    count = len(original_df[original_df['dbscan_cluster'] == cluster_id])
    percentage = (count / len(original_df)) * 100
    print(f"{cluster_name}: {count} records ({percentage:.2f}%)")
# Out:
# ================================================================================
# DBSCAN CLUSTERING RESULTS (eps=3.3) - ORIGINAL DATA
# ================================================================================
#
# ================================================================================
# CLUSTER 0
# Number of records: 1747
# ================================================================================
#   Typhoon Name  Year  Region Province City/Municipality  Families  Person  \
# 0        BETTY  2023       2  BATANES             BASCO      3608   11120
# 1        BETTY  2023       2  BATANES           ITBAYAT       968    3028
# 2        BETTY  2023       2  BATANES             IVANA       444    1532
# 3        BETTY  2023       2  BATANES           MAHATAO       575    1792
# 4        BETTY  2023       2  BATANES           SABTANG       575    1955
# 5        BETTY  2023       2  BATANES            UYUGAN       433    1464
# 6        HENRY  2022       2  BATANES             BASCO         2      10
# 7        JENNY  2023       2  BATANES             BASCO         1       1
# 8        JENNY  2023       2  BATANES           ITBAYAT         6      20
# 9        JENNY  2023       2  BATANES           SABTANG         0     139
#
#    Brgy  Dead  Injured/Ill  ...    PAR_END  Duration_in_PAR_Hours  \
# 0     6     0            0  ...   6/1/2023                  133.0
# 1     5     0            0  ...   6/1/2023                  133.0
# 2     4     0            0  ...   6/1/2023                  133.0
# 3     4     0            0  ...   6/1/2023                  133.0
# 4     6     0            0  ...   6/1/2023                  133.0
# 5     4     0            0  ...   6/1/2023                  133.0
# 6     1     0            0  ...   9/4/2022                   80.2
# 7     1     0            0  ...  10/6/2023                  146.7
# 8     2     0            0  ...  10/6/2023                  146.7
# 9     4     0            0  ...  10/6/2023                  146.7
#
#    Max_Sustained_Wind_kph  Typhoon_Type  Max_24hr_Rainfall_mm  \
# 0                     195           STY                  25.6
# 1                     195           STY                  20.3
# 2                     195           STY                  25.6
# 3                     195           STY                  25.6
# 4                     195           STY                  25.6
# 5                     195           STY                  25.6
# 6                     195           STY                  85.4
# 7                     175            TY                 134.0
# 8                     175            TY                 273.0
# 9                     175            TY                 134.0
#
#    Total_Storm_Rainfall_mm Min_Pressure_hPa Weather_Station_Mapped  \
# 0                    39.00            977.1                      1
# 1                    32.71           1000.5                      1
# 2                    39.00            977.1                      1
# 3                    39.00            977.1                      1
# 4                    39.00            977.1                      1
# 5                    39.00            977.1                      1
# 6                   139.60            994.2                      1
# 7                   224.20            998.9                      1
# 8                   355.80           1000.6                      1
# 9                   224.20            998.9                      1
#
#    Weather_Records_Found Weather_Days_Covered
# 0                      6                    6
# 1                      6                    6
# 2                      6                    6
# 3                      6                    6
# 4                      6                    6
# 5                      6                    6
# 6                      5                    5
# 7                      8                    8
# 8                      8                    8
# 9                      8                    8
#
# [10 rows x 30 columns]
# ================================================================================
# CLUSTER 1
# Number of records: 5
# ================================================================================
#      Typhoon Name  Year  Region       Province City/Municipality  Families  \
# 81         MARING  2021       2        CAGAYAN         SANTA ANA        19
# 264         PAENG  2022       2  NUEVA VIZCAYA            ARITAO        38
# 1173       QUINTA  2020       5    CATANDUANES           GIGMOTO       957
# 1235       JOLINA  2021       5        MASBATE             BALUD         0
# 1465       JOLINA  2021       8  EASTERN SAMAR          LLORENTE      5963
#
#       Person  Brgy  Dead  Injured/Ill  ...     PAR_END  Duration_in_PAR_Hours  \
# 81        88     6     1            0  ...  10/12/2021                  118.0
# 264      142     4     1            1  ...  10/31/2022                  124.7
# 1173    3509     8     3            0  ...  10/27/2020                   71.0
# 1235       0     0     3            1  ...    9/9/2021                  103.0
# 1465   21306     1     0            0  ...    9/9/2021                  103.0
#
#       Max_Sustained_Wind_kph  Typhoon_Type  Max_24hr_Rainfall_mm  \
# 81                       100           STS                 138.4
# 264                      110           STS                  97.4
# 1173                     150            TY                 108.0
# 1235                     120            TY                  95.6
# 1465                     120            TY                  99.5
#
#       Total_Storm_Rainfall_mm Min_Pressure_hPa Weather_Station_Mapped  \
# 81                     227.31            981.4                      1
# 264                    145.40            994.1                      1
# 1173                   197.20            978.4                      1
# 1235                   143.61            997.2                      1
# 1465                   101.50           1002.9                      1
#
#       Weather_Records_Found Weather_Days_Covered
# 81                        6                    6
# 264                       6                    6
# 1173                      5                    5
# 1235                      4                    4
# 1465                      4                    4
#
# [5 rows x 30 columns]
# ================================================================================
# CLUSTER 2
# Number of records: 2
# ================================================================================
#      Typhoon Name  Year  Region       Province City/Municipality  Families  \
# 1450         AMBO  2020       8  EASTERN SAMAR           JIPAPAD      2387
# 1452         AMBO  2020       8  EASTERN SAMAR              ORAS     10491
#
#       Person  Brgy  Dead  Injured/Ill  ...    PAR_END  Duration_in_PAR_Hours  \
# 1450    8655    13     0           42  ...  5/17/2020                  198.0
# 1452   41964    42     2           36  ...  5/17/2020                  198.0
#
#       Max_Sustained_Wind_kph  Typhoon_Type  Max_24hr_Rainfall_mm  \
# 1450                     155            TY                  19.2
# 1452                     155            TY                  15.8
#
#       Total_Storm_Rainfall_mm Min_Pressure_hPa Weather_Station_Mapped  \
# 1450                    70.11            999.5                      1
# 1452                    70.40           1000.2                      1
#
#       Weather_Records_Found Weather_Days_Covered
# 1450                      8                    8
# 1452                      8                    8
#
# [2 rows x 30 columns]
# ================================================================================
# NOISE POINTS (Cluster -1)
# Number of records: 22
# ================================================================================
#      Typhoon Name  Year  Region       Province City/Municipality  Families  \
# 10           KIKO  2021       2        BATANES             BASCO      3043
# 462       KARDING  2022       3        BULACAN        SAN MIGUEL     52600
# 510       KARDING  2022       3    NUEVA ECIJA   CABANATUAN CITY     60550
# 835         ROLLY  2020       5          ALBAY           MALINAO     10570
# 842         ROLLY  2020       5          ALBAY       TABACO CITY     38967
# 1071       QUINTA  2020       5  CAMARINES SUR              BUHI       800
# 1190        ROLLY  2020       5    CATANDUANES             VIRAC     22856
# 1446         AMBO  2020       8  EASTERN SAMAR           ARTECHE      4603
# 1517       AGATON  2022       8          LEYTE            ABUYOG     18957
# 1523       AGATON  2022       8          LEYTE            BAYBAY      4184
#
#       Person  Brgy  Dead  Injured/Ill  ...     PAR_END  Duration_in_PAR_Hours  \
# 10     10656     6     0            0  ...   9/12/2021                  116.0
# 462   191170     9     5            1  ...   9/26/2022                  114.0
# 510   195016    18     0            4  ...   9/26/2022                  114.0
# 835    38530    29     0            0  ...   11/3/2020                  122.0
# 842   146134    47     0            0  ...   11/3/2020                  122.0
# 1071    3735   122     0            0  ...  10/27/2020                   71.0
# 1190   94356    63     0            0  ...   11/3/2020                  122.0
# 1446   18519    20     0           56  ...   5/17/2020                  198.0
# 1517   68354    63    55            0  ...   4/12/2022                   78.0
# 1523   20917    48    95            0  ...   4/12/2022                   78.0
#
#       Max_Sustained_Wind_kph  Typhoon_Type  Max_24hr_Rainfall_mm  \
# 10                       215           STY                 420.7
# 462                      195           STY                  55.8
# 510                      195           STY                  55.8
# 835                      225           STY                 166.7
# 842                      225           STY                 166.7
# 1071                     150            TY                 282.7
# 1190                     225           STY                 238.0
# 1446                     155            TY                  19.2
# 1517                      75            TS                 148.8
# 1523                      75            TS                 148.8
#
#       Total_Storm_Rainfall_mm Min_Pressure_hPa Weather_Station_Mapped  \
# 10                     604.90            927.9                      1
# 462                     73.30            996.4                      1
# 510                     73.30            996.4                      1
# 835                    287.90            981.0                      1
# 842                    287.90            981.0                      1
# 1071                   301.80            981.6                      1
# 1190                   245.80            924.9                      1
# 1446                    70.11            999.5                      1
# 1517                   305.40           1001.2                      1
# 1523                   305.40           1001.2                      1
#
#       Weather_Records_Found Weather_Days_Covered
# 10                        6                    6
# 462                       5                    5
# 510                       5                    5
# 835                       6                    6
# 842                       6                    6
# 1071                      5                    5
# 1190                      6                    6
# 1446                      8                    8
# 1517                      4                    4
# 1523                      4                    4
#
# [10 rows x 30 columns]
# ================================================================================
# CLUSTER SUMMARY
# ================================================================================
# Noise: 22 records (1.24%)
# Cluster 0: 1747 records (98.37%)
# Cluster 1: 5 records (0.28%)
# Cluster 2: 2 records (0.11%)
